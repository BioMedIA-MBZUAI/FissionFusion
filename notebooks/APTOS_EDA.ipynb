# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import defaultdict
import shutil


data_dir = '../dataset/224_data/DR/aptos/'
folders = ['0', '1', '2', '3', '4']

file_paths = []
labels = []

for folder in folders:
    folder_path = os.path.join(data_dir, folder)
    files = os.listdir(folder_path)
    file_paths.extend([os.path.join(folder_path, file) for file in files])
    labels.extend([folder] * len(files))

# %%
train_files, remaining_files, train_labels, remaining_labels = train_test_split(
    file_paths, labels, test_size=0.2, stratify=labels, random_state=9)

val_files, test_files, val_labels, test_labels = train_test_split(
    remaining_files, remaining_labels, test_size=0.5, stratify=remaining_labels, random_state=9)

all_files = train_files + val_files + test_files
all_labels = train_labels + val_labels + test_labels
all_splits = ['train'] * len(train_files) + ['val'] * len(val_files) + ['test'] * len(test_files)

data = {'filename': [os.path.basename(file) for file in all_files],
        'class': all_labels,
        'split': all_splits}
df = pd.DataFrame(data)

csv_filename = 'aptos_dataset_splits.csv'
df.to_csv(csv_filename, index=False)

for split_name in ['train', 'val', 'test']:
    split_data = df[df['split'] == split_name]
    class_counts = split_data['class'].value_counts().sort_index()
    print(f"{split_name.capitalize()} Counts:")
    print(class_counts)
    print()
# Out:
# Train Counts:
# 0    1444
# 1     296
# 2     799
# 3     154
# 4     236
# Name: class, dtype: int64
#
# Val Counts:
# 0    180
# 1     37
# 2    100
# 3     20
# 4     29
# Name: class, dtype: int64
#
# Test Counts:
# 0    181
# 1     37
# 2    100
# 3     19
# 4     30
# Name: class, dtype: int64

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import defaultdict
import shutil


data_dir = '../dataset/224_data/DR/eyepacs/'
folders = ['0', '1', '2', '3', '4']

file_paths = []
labels = []

for folder in folders:
    folder_path = os.path.join(data_dir, folder)
    files = os.listdir(folder_path)
    file_paths.extend([os.path.join(folder_path, file) for file in files])
    labels.extend([folder] * len(files))


train_files, remaining_files, train_labels, remaining_labels = train_test_split(
    file_paths, labels, test_size=0.2, stratify=labels, random_state=9)

val_files, test_files, val_labels, test_labels = train_test_split(
    remaining_files, remaining_labels, test_size=0.5, stratify=remaining_labels, random_state=9)

all_files = train_files + val_files + test_files
all_labels = train_labels + val_labels + test_labels
all_splits = ['train'] * len(train_files) + ['val'] * len(val_files) + ['test'] * len(test_files)

data = {'filename': [file[1:] for file in all_files],
        'class': all_labels,
        'split': all_splits}
df = pd.DataFrame(data)

csv_filename = '../dataset/224_data/DR/eyepacs/eyepacs_dataset_splits.csv'
df.to_csv(csv_filename, index=False)

for split_name in ['train', 'val', 'test']:
    split_data = df[df['split'] == split_name]
    class_counts = split_data['class'].value_counts().sort_index()
    print(f"{split_name.capitalize()} Counts:")
    print(class_counts)
    print()
# Out:
# Train Counts:
# 0    52274
# 1     4964
# 2    10522
# 3     1670
# 4     1531
# Name: class, dtype: int64
#
# Val Counts:
# 0    6534
# 1     620
# 2    1315
# 3     209
# 4     192
# Name: class, dtype: int64
#
# Test Counts:
# 0    6535
# 1     621
# 2    1316
# 3     208
# 4     191
# Name: class, dtype: int64

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import defaultdict
import shutil


data_dir = '../dataset/224_data/DR/messidor/'
folders = ['0', '1', '2', '3']

file_paths = []
labels = []

for folder in folders:
    folder_path = os.path.join(data_dir, folder)
    files = os.listdir(folder_path)
    file_paths.extend([os.path.join(folder_path, file) for file in files])
    labels.extend([folder] * len(files))


train_files, remaining_files, train_labels, remaining_labels = train_test_split(
    file_paths, labels, test_size=0.2, stratify=labels, random_state=9)

val_files, test_files, val_labels, test_labels = train_test_split(
    remaining_files, remaining_labels, test_size=0.5, stratify=remaining_labels, random_state=9)

all_files = train_files + val_files + test_files
all_labels = train_labels + val_labels + test_labels
all_splits = ['train'] * len(train_files) + ['val'] * len(val_files) + ['test'] * len(test_files)

data = {'filename': [file[1:] for file in all_files],
        'class': all_labels,
        'split': all_splits}
df = pd.DataFrame(data)

csv_filename = '../dataset/224_data/DR/messidor/messidor_dataset_splits.csv'
df.to_csv(csv_filename, index=False)

for split_name in ['train', 'val', 'test']:
    split_data = df[df['split'] == split_name]
    class_counts = split_data['class'].value_counts().sort_index()
    print(f"{split_name.capitalize()} Counts:")
    print(class_counts)
    print()
# Out:
# Train Counts:
# 0    437
# 1    122
# 2    198
# 3    203
# Name: class, dtype: int64
#
# Val Counts:
# 0    54
# 1    16
# 2    25
# 3    25
# Name: class, dtype: int64
#
# Test Counts:
# 0    55
# 1    15
# 2    24
# 3    26
# Name: class, dtype: int64

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import defaultdict
import shutil


data_dir = '../dataset/224_data/DR/messidor_2/'
folders = ['0', '1', '2', '3', '4']

file_paths = []
labels = []

for folder in folders:
    folder_path = os.path.join(data_dir, folder)
    files = os.listdir(folder_path)
    file_paths.extend([os.path.join(folder_path, file) for file in files])
    labels.extend([folder] * len(files))


train_files, remaining_files, train_labels, remaining_labels = train_test_split(
    file_paths, labels, test_size=0.2, stratify=labels, random_state=9)

val_files, test_files, val_labels, test_labels = train_test_split(
    remaining_files, remaining_labels, test_size=0.5, stratify=remaining_labels, random_state=9)

all_files = train_files + val_files + test_files
all_labels = train_labels + val_labels + test_labels
all_splits = ['train'] * len(train_files) + ['val'] * len(val_files) + ['test'] * len(test_files)

data = {'filename': [file[1:] for file in all_files],
        'class': all_labels,
        'split': all_splits}
df = pd.DataFrame(data)

csv_filename = '../dataset/224_data/DR/messidor_2/messidor_2_dataset_splits.csv'
df.to_csv(csv_filename, index=False)

for split_name in ['train', 'val', 'test']:
    split_data = df[df['split'] == split_name]
    class_counts = split_data['class'].value_counts().sort_index()
    print(f"{split_name.capitalize()} Counts:")
    print(class_counts)
    print()
# Out:
# Train Counts:
# 0    813
# 1    216
# 2    278
# 3     60
# 4     28
# Name: class, dtype: int64
#
# Val Counts:
# 0    102
# 1     27
# 2     34
# 3      7
# 4      4
# Name: class, dtype: int64
#
# Test Counts:
# 0    102
# 1     27
# 2     35
# 3      8
# 4      3
# Name: class, dtype: int64

# %%
import pandas as pd

# Load the CSV file
file_path = "/share/nvmedata/santosh/CheXpert-v1.0_224/csv/test_labels.csv"  # Replace with the actual file path
df = pd.read_csv(file_path)

# Create the "Frontal/Lateral" column
df["Frontal/Lateral"] = df["Path"].apply(lambda x: "Frontal" if "frontal" in x else "Lateral")

# Save the updated dataframe to a new CSV file
output_file_path = "/share/nvmedata/santosh/CheXpert-v1.0_224/csv/test_labels_v2.csv"  # Replace with the desired output file path
df.to_csv(output_file_path, index=False)

# Print the updated dataframe
print(df)
